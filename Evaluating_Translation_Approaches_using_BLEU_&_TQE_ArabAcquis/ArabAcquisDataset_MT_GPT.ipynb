# %% [markdown]
# # Enriching ArabAcquis Dataset files with OpenAI GPT-3.5-turbo Arabic Translations
#
# This Colab notebook demonstrates the process of further augmenting the ArabAcquis parallel corpus file by adding translations generated by OpenAI's GPT-3.5-turbo model. It takes an input JSON file (already containing original English, reference Arabic, and Google API translations), and for each entry, translates the English text into Arabic using the OpenAI API via the openai Python library. The newly generated GPT-3.5-turbo Arabic translation is then added as an additional field (GPT_translated) to each corresponding entry. Finally, the file is saved to a new JSON file. This step will facilitat a comparative analysis of machine translation outputs from multiple systems against a human reference.
# * **Input file:** ArabAcquis_translated_withGoogleAPI.json (JSON file containing English sentences, original Arabic references, and Google API translations)
# * **Output file:** ArabAcquis_translated_withGoogleAPIandGPT.json (JSON file with an added GPT_translated field containing the OpenAI GPT-3.5-turbo API's Arabic output for each English entry)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ColabData/ArabAcquis Dataset
# Out:
# /content/drive/MyDrive/ColabData/ArabAcquis Dataset

# %%
pip install openai
# Out:
# Collecting openai
#   Downloading openai-1.30.5-py3-none-any.whl (320 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.7/320.7 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.7.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.0 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.18.2)
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.30.5

# %%
import json
from google.colab import userdata

from openai import OpenAI


def load_data(file_path):
    """
    Load the complete data from a JSON file.

    :param file_path: Path to the JSON file.
    :return: Data dictionary loaded from JSON.
    """
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data

def translate_text(key, text, source_language="en", target_language="ar"):
    """
    Translate text from one language to another using OpenAI's GPT-4.

    :param api_key: Your OpenAI API key.
    :param text: Text to translate.
    :param source_language: Source language code (default is English 'en').
    :param target_language: Target language code (default is Arabic 'ar').
    :return: Translated text.
    """
    #openai.api_key = api_key

    client = OpenAI(
        api_key=key
    )

    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "You are a translator."},
            {"role": "user", "content": f"Translate this from {source_language} to {target_language}: {text}"}
        ],
        max_tokens=160,
        temperature=0.3
    )

    return response.choices[0].message.content.strip()

def save_data(data, output_file):
    """
    Save the updated data back to a JSON file.

    :param data: Complete data dictionary with translations.
    :param output_file: Path to the output JSON file.
    """
    with open(output_file, 'w') as file:
        json.dump(data, file, ensure_ascii=False, indent=4)

def main(api_key, input_file, output_file, source_language, target_language):
    data = load_data(input_file)

    for item in range(0,len(data)):
        print(item)
        original_text = data[item]['english']
        translated_text = translate_text(api_key, original_text, source_language, target_language)
        data[item]['GPT_translated'] = translated_text

    save_data(data, output_file)

# Parameters
api_key = userdata.get('GPT_API_KEY')
 # OpenAI API key
input_file = 'ArabAcquis_translated_withGoogleAPI.json'  # Path to original JSON file
output_file = 'ArabAcquis_translated_withGoogleAPIandGPT.json'  # File to save the dataset with translations
source_language = 'en'  # Source language
target_language = 'ar'  # Target language (Arabic)

main(api_key, input_file, output_file, source_language, target_language)

# %%
import json

with open('ArabAcquis_translated_withGoogleAPIandGPT.json', 'r') as datafile:
  data = json.load(datafile)

len(data)

data[0:5]
# Out:
# [{'english': 'THE COUNCIL OF THE EUROPEAN ECONOMIC COMMUNITY,',
#   'arabic': 'مجلس الجماعة الاقتصادية الأوروبية',
#   'googleAPI_translated': 'إن مجلس الجماعة الاقتصادية الأوروبية،',
#   'GPT_translated': 'مجلس الاتحاد الاقتصادي الأوروبي'},
#  {'english': 'Whereas the adoption of a common transport policy involves inter alia laying down common rules for the international carriage of goods by road to or from the territory of a Member State or passing across the territory of one or more Member States;',
#   'arabic': 'حيث أن اعتماد سياسة نقل مشتركة تنطوي من بين أمور أخرى على وضع قواعد مشتركة للنقل الدولي للبضائع عن طريق البر أو من أراضي دولة عضو أو المرور عبر أراضي واحدة من الدول الأعضاء أو أكثر؛',
#   'googleAPI_translated': 'ولما كان اعتماد سياسة نقل مشتركة يتضمن، في جملة أمور، وضع قواعد مشتركة للنقل الدولي للبضائع عن طريق البر من وإلى أراضي دولة عضو أو المرور عبر أراضي دولة عضو واحدة أو أكثر؛',
#   'GPT_translated': 'بينما ينطوي اعتماد سياسة نقل مشتركة على وضع قواعد مشتركة لنقل البضائع عبر الطرق الدولية إلى أو من أراضي دولة عضو أو عبر أراضي دولة أو أكثر من الدول الأعضاء.'},
#  {'english': 'Article 1',
#   'arabic': 'المادة 1',
#   'googleAPI_translated': 'المادة 1',
#   'GPT_translated': 'المادة 1'},
#  {'english': '3. The types of carriage listed in Annex II shall no longer be subject to a quota system. They may, however, remain subject to authorisation provided no quantitative restriction is involved ; in such case Member States shall ensure that decisions on applications for authorisation are given within five days of receipt.',
#   'arabic': '3. لا تخضع أنواع النقل المدرجة في الملحق الثاني لنظام الحصص. بيد أنها قد تبقى خاضعة للترخيص شرط عدم وجود أي قيود على الكميات؛ وفي هذه الحالة، تضمن الدول الأعضاء إصدار القرارات بشأن طلبات الترخيص خلال خمسة أيام من الاستلام.',
#   'googleAPI_translated': '3. لن تظل أنواع النقل المدرجة في الملحق الثاني خاضعة لنظام الحصص. ومع ذلك، يجوز أن تظل خاضعة للترخيص بشرط عدم وجود قيود كمية؛ وفي مثل هذه الحالة، يجب على الدول الأعضاء التأكد من صدور القرارات المتعلقة بطلبات الترخيص في غضون خمسة أيام من استلامها.',
#   'GPT_translated': '3. أنواع النقل المدرجة في المرفق الثاني لن تكون معرضة لنظام الحصص الكمية بعد الآن. ومع ذلك، قد تبقى معرضة للترخيص شريطة عدم وجود قيود كمية؛ في هذه الحالة يجب على الدول الأعضاء ضمان أن تتخذ قرارات بشأن طلبات الترخيص خلال خمسة أيام'},
#  {'english': 'Member States shall inform the Commission of the measures taken to implement this Directive within three months of its entry into force and in any event before the end of 1962.',
#   'arabic': 'تبلغ الدول الأعضاء المفوضية الأوروبية بالتدابير المتخذة لتنفيذ هذا التوجيه خلال ثلاثة أشهر من دخوله حيز التنفيذ وبأي حال قبل نهاية عام 1962.',
#   'googleAPI_translated': 'يجب على الدول الأعضاء إبلاغ المفوضية بالتدابير المتخذة لتنفيذ هذا التوجيه في غضون ثلاثة أشهر من دخوله حيز التنفيذ وعلى أي حال قبل نهاية عام 1962.',
#   'GPT_translated': 'يجب على الدول الأعضاء إبلاغ المفوضية بالإجراءات المتخذة لتنفيذ هذا التوجيه خلال ثلاثة أشهر من دخوله حيز التنفيذ وعلى أي حال قبل نهاية عام 1962.'}]

# %%
data[0:20]
# Out:
# [{'english': 'THE COUNCIL OF THE EUROPEAN ECONOMIC COMMUNITY,',
#   'arabic': 'مجلس الجماعة الاقتصادية الأوروبية',
#   'googleAPI_translated': 'إن مجلس الجماعة الاقتصادية الأوروبية،',
#   'GPT_translated': 'مجلس الاتحاد الاقتصادي الأوروبي'},
#  {'english': 'Whereas the adoption of a common transport policy involves inter alia laying down common rules for the international carriage of goods by road to or from the territory of a Member State or passing across the territory of one or more Member States;',
#   'arabic': 'حيث أن اعتماد سياسة نقل مشتركة تنطوي من بين أمور أخرى على وضع قواعد مشتركة للنقل الدولي للبضائع عن طريق البر أو من أراضي دولة عضو أو المرور عبر أراضي واحدة من الدول الأعضاء أو أكثر؛',
#   'googleAPI_translated': 'ولما كان اعتماد سياسة نقل مشتركة يتضمن، في جملة أمور، وضع قواعد مشتركة للنقل الدولي للبضائع عن طريق البر من وإلى أراضي دولة عضو أو المرور عبر أراضي دولة عضو واحدة أو أكثر؛',
#   'GPT_translated': 'بينما ينطوي اعتماد سياسة نقل مشتركة على وضع قواعد مشتركة لنقل البضائع عبر الطرق الدولية إلى أو من أراضي دولة عضو أو عبر أراضي دولة أو أكثر من الدول الأعضاء.'},
#  {'english': 'Article 1',
#   'arabic': 'المادة 1',
#   'googleAPI_translated': 'المادة 1',
#   'GPT_translated': 'المادة 1'},
#  {'english': '3. The types of carriage listed in Annex II shall no longer be subject to a quota system. They may, however, remain subject to authorisation provided no quantitative restriction is involved ; in such case Member States shall ensure that decisions on applications for authorisation are given within five days of receipt.',
#   'arabic': '3. لا تخضع أنواع النقل المدرجة في الملحق الثاني لنظام الحصص. بيد أنها قد تبقى خاضعة للترخيص شرط عدم وجود أي قيود على الكميات؛ وفي هذه الحالة، تضمن الدول الأعضاء إصدار القرارات بشأن طلبات الترخيص خلال خمسة أيام من الاستلام.',
#   'googleAPI_translated': '3. لن تظل أنواع النقل المدرجة في الملحق الثاني خاضعة لنظام الحصص. ومع ذلك، يجوز أن تظل خاضعة للترخيص بشرط عدم وجود قيود كمية؛ وفي مثل هذه الحالة، يجب على الدول الأعضاء التأكد من صدور القرارات المتعلقة بطلبات الترخيص في غضون خمسة أيام من استلامها.',
#   'GPT_translated': '3. أنواع النقل المدرجة في المرفق الثاني لن تكون معرضة لنظام الحصص الكمية بعد الآن. ومع ذلك، قد تبقى معرضة للترخيص شريطة عدم وجود قيود كمية؛ في هذه الحالة يجب على الدول الأعضاء ضمان أن تتخذ قرارات بشأن طلبات الترخيص خلال خمسة أيام'},
#  {'english': 'Member States shall inform the Commission of the measures taken to implement this Directive within three months of its entry into force and in any event before the end of 1962.',
#   'arabic': 'تبلغ الدول الأعضاء المفوضية الأوروبية بالتدابير المتخذة لتنفيذ هذا التوجيه خلال ثلاثة أشهر من دخوله حيز التنفيذ وبأي حال قبل نهاية عام 1962.',
#   'googleAPI_translated': 'يجب على الدول الأعضاء إبلاغ المفوضية بالتدابير المتخذة لتنفيذ هذا التوجيه في غضون ثلاثة أشهر من دخوله حيز التنفيذ وعلى أي حال قبل نهاية عام 1962.',
#   'GPT_translated': 'يجب على الدول الأعضاء إبلاغ المفوضية بالإجراءات المتخذة لتنفيذ هذا التوجيه خلال ثلاثة أشهر من دخوله حيز التنفيذ وعلى أي حال قبل نهاية عام 1962.'},
#  {'english': 'Article 4',
#   'arabic': 'المادة 4',
#   'googleAPI_translated': 'المادة 4',
#   'GPT_translated': 'المادة ٤'},
#  {'english': 'THE COMMISSION OF THE EUROPEAN COMMUNITIES,',
#   'arabic': 'مفوضية الجماعات الأوروبية',
#   'googleAPI_translated': 'إن لجنة الجماعات الأوروبية،',
#   'GPT_translated': 'لجنة الجماعات الأوروبية'},
#  {'english': 'Whereas, in accordance with Article 17 (4) of Regulation No 359/67/EEC, the refund applicable on the day on which the application for an export licence is made may be applied to an export made during the period of validity of the licence and whereas, in that case, a corrective amount is applied to the refund ; whereas, in accordance with Article 1 of Commission Regulation No 474/67/EEC 2 of 21 August 1967 on the advance fixing of the export refund on rice and broken rice, the corrective amount is equal to the difference between the c.i.f. price and c.i.f. forward delivery price;',
#   'arabic': 'حيث أنه، ووفقاً للمادة 17 (4) من النظام رقم 359/67/EEC، يمكن تطبيق الاسترداد المستحق في اليوم الذي يتم فيه تقديم طلب رخصة التصدير، على عملية تصدير تجرى خلال فترة صلاحية الرخصة وحيث أنه، في هذه الحالة، يتم إضافة مبلغ تصحيحي على القيمة المستردة؛ وحيث أن المبلغ التصحيحي، ووفقاً للمادة 1 من نظام المفوضية الأوروبية رقم 474/67/EEC 2  المؤرخ في 21 أغسطس/آب 1967 بشأن التحديد المسبق لاسترداد أموال تصدير الأرز وكسر الأرز، يساوي الفرق بين سعر التكلفة والتأمين ومصاريف الشحن وسعر التكلفة والتأمين ومصاريف الشحن الآجل؛',
#   'googleAPI_translated': 'وحيث إنه، وفقًا للمادة 17 (4) من اللائحة رقم 359/67/EEC، يجوز تطبيق استرداد المبلغ المطبق في اليوم الذي يتم فيه تقديم طلب الحصول على ترخيص التصدير على عملية تصدير تمت خلال فترة صلاحية الترخيص وحيث أنه في هذه الحالة يتم تطبيق مبلغ تصحيحي على الاسترداد؛ في حين أنه وفقًا للمادة 1 من لائحة المفوضية رقم 474/67/EEC 2 المؤرخة 21 أغسطس 1967 بشأن التثبيت المسبق لاسترداد الصادرات على الأرز والأرز المكسور، فإن المبلغ التصحيحي يساوي الفرق بين c.i.f. السعر و سيف سعر التسليم الآجل؛',
#   'GPT_translated': 'بينما، وفقًا للمادة 17 (4) من اللائحة رقم 359/67/EEC، يمكن تطبيق الاسترداد المعمول به في اليوم الذي تُقدم فيه طلب ترخيص التصدير على التصدير الذي تم خلال فترة صلاحية الترخيص وبينما، في هذه الحالة، يتم تطبيق مبلغ تصحيحي على الاسترداد؛ ب'},
#  {'english': 'Whereas the measures provided for in this Regulation are in accordance with the Opinion of the Management Committee for Cereals;',
#   'arabic': 'حيث أن التدابير المنصوص عليها في هذا النظام تتماشى مع رأي لجنة إدارة الحبوب؛',
#   'googleAPI_translated': 'ولما كانت الإجراءات المنصوص عليها في هذا النظام تتوافق مع رأي لجنة إدارة الحبوب،',
#   'GPT_translated': 'بينما تتماشى التدابير المنصوص عليها في هذا اللائحة مع رأي اللجنة الإدارية للحبوب؛'},
#  {'english': 'The following shall be substituted for the first two subparagraphs of Article 1 of Regulation No 474/67/EEC:',
#   'arabic': 'يُستبدل ما يلي بالفقرتين الفرعيتين الأولييين من المادة 1 من النظام رقم 474/67/EEC:',
#   'googleAPI_translated': 'يتم استبدال الفقرتين الفرعيتين الأوليين من المادة 1 من اللائحة رقم 474/67/EEC بما يلي:',
#   'GPT_translated': 'التالي يجب أن يحل محل الفقرتين الأوليين من المادة 1 من اللائحة رقم 474/67/EEC:'},
#  {'english': 'In the intervals between weekly fixings the amount of the refund applicable in the case of advance fixing shall be adjusted only when application of the above-mentioned provision would lead to its amount being altered by more than 0 7025 units of account per 100 kilogrammes."',
#   'arabic': 'في الفترات الفاصلة الأسبوعية بين عمليات تحديد المبالغ الواجب استردادها، تُعدل قيمة الاسترداد المعمول بها في حالة التحديد المسبق فقط عندما يؤدي تطبيق الحكم المذكور أعلاه إلى تعديل قيمته بأكثر من 0 7025 وحدة حسابية لكل 100 كيلوغرام".',
#   'googleAPI_translated': 'في الفترات الفاصلة بين عمليات التثبيت الأسبوعية، لا يتم تعديل مبلغ الاسترداد المطبق في حالة التثبيت المسبق إلا عندما يؤدي تطبيق الشرط المذكور أعلاه إلى تغيير مبلغه بأكثر من 07025 وحدة حسابية لكل 100 كيلوغرام."',
#   'GPT_translated': 'في الفترات بين التثبيتات الأسبوعية، سيتم ضبط مبلغ الاسترداد المعمول به في حالة التثبيت المسبق فقط عندما يؤدي تطبيق البند المذكور أعلاه إلى تغيير مبلغه بمقدار أكثر من 0.7025 وحدة حساب لكل 100 كيلوغرام.'},
#  {'english': 'COUNCIL DIRECTIVE of 20 March 1970 on the approximation of the laws of the Member States relating to measures to be taken against air pollution by gases from positive-ignition engines of motor vehicles (70/220/EEC)',
#   'arabic': 'توجيه المجلس الصادر بتاريخ 20 مارس/آذار 1970 بشأن تقريب قوانين الدول الأعضاء المتعلقة بالتدابير الواجب اتخاذها لمكافحة تلوث الهواء بغازات محركات الإشعال الإيجابي للمركبات الآلية (70/220/EEC)',
#   'googleAPI_translated': 'توجيه المجلس الصادر في 20 مارس 1970 بشأن تقريب قوانين الدول الأعضاء فيما يتعلق بالتدابير الواجب اتخاذها ضد تلوث الهواء بالغازات المنبعثة من محركات الاشتعال الإيجابي للسيارات (70/220/EEC)',
#   'GPT_translated': 'توجيه المجلس بتاريخ 20 مارس 1970 بشأن تقريب قوانين الدول الأعضاء المتعلقة بالتدابير التي يجب اتخاذها ضد تلوث الهواء بالغازات من محركات السيارات ذات الإشعال الإيجابي (70/220/EEC)'},
#  {'english': 'Having regard to the proposal from the Commission;',
#   'arabic': 'مع الأخذ في الاعتبار الاقتراح المقدم من المفوضية الأوروبية؛',
#   'googleAPI_translated': 'وبعد النظر في اقتراح اللجنة،',
#   'GPT_translated': 'بناءً على الاقتراح من اللجنة؛'},
#  {'english': 'Whereas a regulation of 14 October 1968 amending the Straßenverkehrs-Zulassungs-Ordnung was published in Germany in the Bundesgesetzblatt Part I of 18 October 1968 ; whereas that regulation contains provisions on measures to be taken against air pollution by positive-ignition engines of motor vehicles ; whereas those provisions will enter into force on 1 October 1970;',
#   'arabic': 'حيث أن النظام الصادر في 14 أكتوبر/تشرين الأول 1968 الذي يعدّل Straßenverkehrs-Zulassungs-Ordnung (التشريع الألماني لتراخيص السوق) نُشر في ألمانيا في  Bundesgesetzblatt (الجريدة الرسمية) الجزء I في 18 أكتوبر/تشرين الأول 1968؛ وحيث أن هذا النظام يتضمن أحكاماً تتعلق بالتدابير الواجب اتخاذها لمكافحة تلوث الهواء الذي تتسبب به محركات الإشعال الإيجابي للمركبات الآلية؛ وحيث أن هذه الأحكام ستندخل حيز التنفيذ في 1 أكتوبر/تشرين الأول 1970؛',
#   'googleAPI_translated': 'حيث أن اللائحة الصادرة في 14 أكتوبر 1968 والتي تعدل Straßenverkehrs-Zulassungs-Ordnung تم نشرها في ألمانيا في الجزء الأول من Bundesgesetzblatt بتاريخ 18 أكتوبر 1968؛ حيث أن تلك اللائحة تتضمن أحكامًا بشأن التدابير التي يتعين اتخاذها ضد تلوث الهواء الناجم عن محركات الاشتعال الإيجابي في السيارات؛ وحيث أن هذه الأحكام سوف تدخل حيز التنفيذ في 1 أكتوبر 1970؛',
#   'GPT_translated': 'في حين تم نشر تنظيم بتاريخ 14 أكتوبر 1968 يعدل تنظيم ترخيص حركة المرور على الطرق في ألمانيا في الجريدة الرسمية الاتحادية الجزء الأول بتاريخ 18 أكتوبر 1968؛ حيث يحتوي هذا التنظيم على أحكام بشأن التدابير التي يجب اتخاذها ضد تلوث الهواء ب'},
#  {'english': 'Whereas, on the basis of that communication, each Member State requested to grant national type approval of a type of vehicle must be able to ascertain whether that type has been submitted to the tests laid down in this Directive ; whereas, to this end, each Member State should inform the other Member States of its findings by sending them a copy of the communication completed for each type of motor vehicle which has been tested;',
#   'arabic': 'حيث أنه، وعلى أساس هذا الإبلاغ، يتعيّن على كل دولة عضو يُطلب منها منح الموافقة الوطنية على أحد أنواع المركبات، أن تتمكن من التأكد ما إذا كان هذا النوع قد خضع للاختبارات الواردة في هذا التوجيه؛ وحيث أنه، ولتحقيق هذه الغاية، يتعين على كل دولة عضو إبلاغ الدول الأعضاء الأخرى بالنتائج التي تتوصل إليها عن طريق إرسال نسخة عن الإبلاغ المملوء عن كل نوع من أنواع المركبات الآلية التي جرى اختبارها؛',
#   'googleAPI_translated': 'وحيث أنه، على أساس هذا الاتصال، فإن كل دولة عضو تطلب منح الموافقة على النوع الوطني لنوع من المركبات يجب أن تكون قادرة على التأكد مما إذا كان هذا النوع قد خضع للاختبارات المنصوص عليها في هذا التوجيه؛ حيث أنه، تحقيقًا لهذه الغاية، يجب على كل دولة عضو إبلاغ الدول الأعضاء الأخرى بالنتائج التي توصلت إليها عن طريق إرسال نسخة من البلاغ المكتمل لكل نوع من المركبات الآلية التي تم اختبارها؛',
#   'GPT_translated': 'بينما، بناءً على تلك الاتصالات، يجب على كل دولة عضو طلب منح الموافقة النوعية الوطنية لنوع من السيارات أن تكون قادرة على التحقق مما إذا كان قد تم تقديم هذا النوع للاختبارات المنصوص عليها في هذا التوجيه؛ حيث يجب على كل دولة عضو، لهذا الغرض، إ'},
#  {'english': 'Article 1',
#   'arabic': 'المادة 1',
#   'googleAPI_translated': 'المادة 1',
#   'GPT_translated': 'المادة 1'},
#  {'english': 'No Member State may refuse to grant EEC type approval or national type approval of a vehicle on grounds relating to air pollution by gases from positive-ignition engines of motor vehicles: - from 1 October 1970, where that vehicle satisfies both the requirements contained in Annex I, with the exception of those in items 3.2.1.1 and 3.2.2.1, and the requirements contained in Annexes II, IV, V and VI;',
#   'arabic': 'لا يحق لأي دولة عضو أن ترفض منح موافقة الجماعة الإقتصادية الأوروبية على النوع أو الموافقة الوطنية على نوع مركبة لأسباب تتعلق بتلوث الهواء بغازات من محركات الإشعال الإيجابي للمركبات الآلية: - اعتباراً من 1 أكتوبر/تشرين الأول 1970، إن كانت هذه المركبة تلبي الشروط الواردة في الملحق I، باستثناء تلك الواردة في البندين 3.2.1.1 و3.2.2.1 والشروط الواردة في الملاحق II، IV، V، VI؛',
#   'googleAPI_translated': 'لا يجوز لأي دولة عضو أن ترفض منح موافقة الجماعة الاقتصادية الأوروبية أو موافقة النوع الوطني لمركبة لأسباب تتعلق بتلوث الهواء بواسطة الغازات المنبعثة من محركات الاشتعال الإيجابي للمركبات: - اعتبارًا من 1 أكتوبر 1970، عندما تستوفي تلك المركبة كلا المتطلبات الواردة في الملحق I، باستثناء تلك الواردة في البنود 3.2.1.1 و3.2.2.1، والمتطلبات الواردة في المرفقات الثاني والرابع والخامس والسادس؛',
#   'GPT_translated': 'لا يجوز لأي دولة عضو رفض منح الموافقة على نوع EEC أو الموافقة الوطنية على مركبة بسبب تلوث الهواء بالغازات من محركات الاحتراق الإيجابي للمركبات: - اعتبارًا من 1 أكتوبر 1970، حيث تستوفي تلك المركبة كل من المتطلبات الواردة في المرفق الأول، باستثناء'},
#  {'english': '1. On application being made by a manufacturer or his authorised representative, the competent authorities of the Member State concerned shall complete the sections of the communication provided for in Annex VII. A copy of that communication shall be sent to the other Member States and to the applicant. Other Member States which are requested to grant national type approval for the same type of vehicle shall accept that document as proof that the tests provided for have been carried out.',
#   'arabic': '1. بناءً على طلب مقدم من قبل المصنع أو ممثله، تستكمل السلطات المختصة في الدولة العضو المعنية أقسام الإبلاغ المنصوص عليه في الملحق VII.  وتُرسَل نسخة عن هذا الإبلاغ إلى الدول الأعضاء الأخرى وإلى مقدّم الطلب. وتقبل الدول الأعضاء الأخرى المطلوب منها منح الموافقة الوطنية على النوع للنوع نفسه من المركبات، هذه الوثيقة كدليل على تنفيذ الاختبارات المنصوص عليها.',
#   'googleAPI_translated': '1. عند تقديم الطلب من قبل الشركة المصنعة أو ممثله المعتمد، يجب على السلطات المختصة في الدولة العضو المعنية استكمال أقسام البلاغ المنصوص عليها في الملحق السابع. وترسل نسخة من هذا البلاغ إلى الدول الأعضاء الأخرى وإلى مقدم الطلب. ويجب على الدول الأعضاء الأخرى التي يُطلب منها منح الموافقة على النوع الوطني لنفس النوع من المركبات أن تقبل تلك الوثيقة كدليل على إجراء الاختبارات المنصوص عليها.',
#   'GPT_translated': 'عند تقديم طلب من قبل الشركة المصنعة أو ممثلها المعتمد، يجب على السلطات المختصة في الدولة العضو المعنية إكمال أقسام الاتصال المنصوص عليها في المرفق السابع. يجب إرسال نسخة من هذا الاتصال إلى الدول الأعضاء الأخرى وإلى طالب الطلب. يجب على الدول الأعضاء الأ'},
#  {'english': 'The Member State which has granted type approval shall take the necessary measures to ensure that it is informed of any modification of a part or characteristic referred to in item 1.1 of Annex I. The competent authorities of that Member State shall determine whether fresh tests should be carried out on the modified prototype and whether a fresh report should be drawn up. Where such tests reveal failure to comply with the requirements of this Directive, the modification shall not be approved.',
#   'arabic': 'يتعين على الدولة العضو التي منحت الموافقة على النوع أن تتخذ التدابير اللازمة لضمان إبلاغها بأي تعديلات تجرى على جزء أو مميزات مشار إليها في البند 1.1 من الملحق I. ويتعين على السلطات المختصة في هذه الدولة العضو أن تحدد ما إذا كان يتوجب إجراء اختبارات جديدة على النموذج المعدّل أو ما إذا كان يتعين إعداد تقرير جديد. وفي حال أظهرت هذه الاختبارات عدم الامتثال لشروط هذا التوجيه، لا يتم الموافقة على التعديل.',
#   'googleAPI_translated': 'يجب على الدولة العضو التي منحت الموافقة النوعية اتخاذ الإجراءات اللازمة لضمان إبلاغها بأي تعديل في الجزء أو الخاصية المشار إليها في البند 1.1 من الملحق الأول. وتحدد السلطات المختصة في تلك الدولة العضو ما إذا كان ينبغي إجراء اختبارات جديدة تم تنفيذها على النموذج الأولي المعدل وما إذا كان ينبغي إعداد تقرير جديد. عندما تكشف هذه الاختبارات عن عدم الامتثال لمتطلبات هذا التوجيه، فلن تتم الموافقة على التعديل.',
#   'GPT_translated': 'الدولة العضو التي منحت الموافقة على النوع يجب أن تتخذ التدابير اللازمة لضمان أنها مطلعة على أي تعديل في جزء أو خاصية مشار إليها في البند 1.1 من المرفق الأول. وتحدد السلطات المختصة في تلك الدولة العضو ما إذا كان يجب إجراء اختبارات جديدة على النموذج الم'},
#  {'english': 'Article 6',
#   'arabic': 'المادة 6',
#   'googleAPI_translated': 'المادة 6',
#   'GPT_translated': 'المادة 6'}]
